# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("property_prices_data.csv")
df
# Out:
#       Property ID     Location   Region  Size (sq ft)  Number of Bedrooms  \
# 0         P000001  Location 33     West          3793                   3
# 1         P000002   Location 7  Central          2657                   5
# 2         P000003  Location 46     East          2516                   5
# 3         P000004  Location 16  Central          2569                   2
# 4         P000005  Location 10  Central          4143                   5
# ...           ...          ...      ...           ...                 ...
# 99995     P099996   Location 1    South          3406                   3
# 99996     P099997  Location 31    North          1005                   1
# 99997     P099998  Location 19  Central          2606                   2
# 99998     P099999  Location 41     West          2684                   5
# 99999     P100000   Location 8    North          2371                   1
#
#        Number of Bathrooms  Year Built  Has Garage  Has Garden  \
# ...

# %%
df.head()
# Out:
#   Property ID     Location   Region  Size (sq ft)  Number of Bedrooms  \
# 0     P000001  Location 33     West          3793                   3
# 1     P000002   Location 7  Central          2657                   5
# 2     P000003  Location 46     East          2516                   5
# 3     P000004  Location 16  Central          2569                   2
# 4     P000005  Location 10  Central          4143                   5
#
#    Number of Bathrooms  Year Built  Has Garage  Has Garden  Has Swimming Pool  \
# 0                    2        2004       False       False               True
# 1                    2        2013        True       False              False
# 2                    2        2021        True       False               True
# 3                    1        1990        True        True               True
# 4                    1        2023       False       False              False
#
#    Nearby Schools  Nearby Hospitals  Nearby Shopping Malls   Price ($)  \
# ...

# %%
df.tail()
# Out:
#       Property ID     Location   Region  Size (sq ft)  Number of Bedrooms  \
# 99995     P099996   Location 1    South          3406                   3
# 99996     P099997  Location 31    North          1005                   1
# 99997     P099998  Location 19  Central          2606                   2
# 99998     P099999  Location 41     West          2684                   5
# 99999     P100000   Location 8    North          2371                   1
#
#        Number of Bathrooms  Year Built  Has Garage  Has Garden  \
# 99995                    1        1921        True       False
# 99996                    1        1986       False       False
# 99997                    3        1938       False        True
# 99998                    3        1936       False        True
# 99999                    3        2020        True       False
#
#        Has Swimming Pool  Nearby Schools  Nearby Hospitals  \
# 99995               True               4                 2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Property ID            100000 non-null  object
#  1   Location               100000 non-null  object
#  2   Region                 100000 non-null  object
#  3   Size (sq ft)           100000 non-null  int64
#  4   Number of Bedrooms     100000 non-null  int64
#  5   Number of Bathrooms    100000 non-null  int64
#  6   Year Built             100000 non-null  int64
#  7   Has Garage             100000 non-null  bool
#  8   Has Garden             100000 non-null  bool
#  9   Has Swimming Pool      100000 non-null  bool
#  10  Nearby Schools         100000 non-null  int64
#  11  Nearby Hospitals       100000 non-null  int64
#  12  Nearby Shopping Malls  100000 non-null  int64
#  13  Price ($)              100000 non-null  float64
# ...

# %%
df.describe()
# Out:
#         Size (sq ft)  Number of Bedrooms  Number of Bathrooms     Year Built  \
# count  100000.000000       100000.000000        100000.000000  100000.000000
# mean     2751.035670            2.999160             2.000460    1961.363740
# std      1297.723664            1.414192             0.818234      35.847973
# min       500.000000            1.000000             1.000000    1900.000000
# 25%      1629.000000            2.000000             1.000000    1930.000000
# 50%      2750.000000            3.000000             2.000000    1961.000000
# 75%      3871.000000            4.000000             3.000000    1992.000000
# max      4999.000000            5.000000             3.000000    2023.000000
#
#        Nearby Schools  Nearby Hospitals  Nearby Shopping Malls     Price ($)  \
# count   100000.000000      100000.00000          100000.000000  1.000000e+05
# mean         1.998800           0.99753               0.998850  1.025733e+06
# ...

# %%
df.isnull().sum()
# Out:
# Property ID              0
# Location                 0
# Region                   0
# Size (sq ft)             0
# Number of Bedrooms       0
# Number of Bathrooms      0
# Year Built               0
# Has Garage               0
# Has Garden               0
# Has Swimming Pool        0
# Nearby Schools           0
# Nearby Hospitals         0
# Nearby Shopping Malls    0
# Price ($)                0
# Last Renovation Year     0
# Property Type            0
# Owner Name               0
# Owner Contact            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.groupby("Property ID")

# %%
region_counts = df["Region"].value_counts()

plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")

pista_palette = ["#22b0cf"] * len(region_counts)  # Ensuring uniform color

ax = sns.barplot(x=region_counts.index, y=region_counts.values, palette=pista_palette, edgecolor="black")

# Adding labels at the center of each bar
for p in ax.patches:
    ax.annotate(f'{int(p.get_height())}', 
                (p.get_x() + p.get_width() / 2, p.get_height() / 2),  # Center of the bar
                ha='center', va='center', fontsize=12, color='black', fontweight='bold')

plt.xlabel("Region")
plt.ylabel("Number of Properties")
plt.title("Number of Properties in Each Region")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\3805397604.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=region_counts.index, y=region_counts.values, palette=pista_palette, edgecolor="black")

# %%
# Filter data for the 'Central' region
central_region_data = df[df["Region"] == "Central"]

# Count properties per location within Central region
central_location_counts = central_region_data["Location"].value_counts()

# Select the top 5 locations with the most properties
top_5_locations = central_location_counts.head(5)

# Plot bar chart
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")  # Add grid background
ax = sns.barplot(x=top_5_locations.index, y=top_5_locations.values, palette="viridis")

# Add exact count labels on top of each bar
for index, value in enumerate(top_5_locations.values):
    plt.text(index, value + 5, str(value), ha="center", fontsize=12, fontweight="bold")

# Add labels and title
plt.xlabel("Location in Central Region")
plt.ylabel("Number of Properties")
plt.title("Top 5 Locations with Most Properties in Central Region")
plt.xticks(rotation=45)

# Add a grid
plt.grid(axis="y", linestyle="--", alpha=0.7)

# Show the plot
plt.show()
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\2902655757.py:13: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=top_5_locations.index, y=top_5_locations.values, palette="viridis")

# %%
location_prices = df.groupby("Location")["Price ($)"].mean().sort_values(ascending=False)

# Select top 5 locations
top_5_prices = location_prices.head(5)
pista_palette = ["#22b0cf", "#22b0cf", "#22b0cf", "#22b0cf", "#22b0cf"]

# Plot
plt.figure(figsize=(10, 6))
sns.set_style("whitegrid")
ax = sns.barplot(x=top_5_prices.index, y=top_5_prices.values, palette=pista_palette, edgecolor="black")

# Labels
plt.xlabel("Location")
plt.ylabel("Average Property Price")
plt.title("Top 5 Locations with Highest Average Property Prices")
plt.xticks(rotation=45)

# Show values on bars
for index, value in enumerate(top_5_prices.values):
    plt.text(index, value + 5000, f"{int(value)}", ha="center", fontsize=12, fontweight="bold")

# Show the plot
plt.show()
plt.savefig('plot1.png')
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\3490164019.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=top_5_prices.index, y=top_5_prices.values, palette=pista_palette, edgecolor="black")

# %%
# What is the average property price in Location 1 compared to other locations?
plt.figure(figsize=(6, 4))
sns.set_style("whitegrid")
ax = sns.barplot(x=["Location 1"], y=[df["Price ($)"].mean()], palette="Blues")

# Labels
plt.xlabel("Location")
plt.ylabel("Average Property Price")
plt.title("Average Property Price in Location 1")

# Show value on the bar
plt.text(0, df["Price ($)"].mean() + 5000, 
         f"${int(df['Price ($)'].mean())}", 
         ha="center", fontsize=12, fontweight="bold")

# Show plot
plt.show()
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\604790706.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(x=["Location 1"], y=[df["Price ($)"].mean()], palette="Blues")

# %%
# How does the price distribution vary in Location 1? Are there more budget-friendly or high-end properties?
location_1_data = df[df["Location"] == "Location 1"]

# Plot distribution
plt.figure(figsize=(8, 5))
sns.set_style("whitegrid")
sns.histplot(location_1_data["Price ($)"], bins=30, kde=True, color="royalblue")

# Labels
plt.xlabel("Property Price ($)")
plt.ylabel("Frequency")
plt.title("Price Distribution in Location 1")

# Show plot
# Out:
# Text(0.5, 1.0, 'Price Distribution in Location 1')

# %%
# How do property prices trend over the years in Location 1?
location_1_data = df[df["Location"] == "Location 1"]

# Plot price trend over the years
plt.figure(figsize=(8, 5))
sns.set_style("whitegrid")
ax = sns.lineplot(x=location_1_data["Year Built"], y=location_1_data["Price ($)"], marker="o", color="royalblue")

# Labels
plt.xlabel("Year Built")
plt.ylabel("Average Property Price ($)")
plt.title("Property Price Trend in Location 1")

# Show plot
plt.show()

# %%
# What is the average size (sq. ft.) of properties in Location 1?
# How does the property size correlate with the number of bedrooms and bathrooms?
location_1_data = df[df["Location"] == "Location 1"]

# Calculate average size
avg_size = location_1_data["Size (sq ft)"].mean()

# Plot
plt.figure(figsize=(6, 4))
sns.barplot(x=["Location 1"], y=[avg_size], palette="Blues")

# Labels
plt.xlabel("Location")
plt.ylabel("Average Size (sq. ft.)")
plt.title("Average Property Size in Location 1")

# Show value on the bar
plt.text(0, avg_size + 50, f"{int(avg_size)} sq. ft.", ha="center", fontsize=12, fontweight="bold")

plt.show()
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\143606850.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=["Location 1"], y=[avg_size], palette="Blues")

# %%
# How does the property size correlate with the number of bedrooms and bathrooms?
location_1_data = df[df["Location"] == "Location 1"]

# Scatter plot
plt.figure(figsize=(8, 5))
sns.scatterplot(x=location_1_data["Size (sq ft)"], y=location_1_data["Number of Bedrooms"], color="royalblue", alpha=0.7)
sns.scatterplot(x=location_1_data["Size (sq ft)"], y=location_1_data["Number of Bathrooms"], color="seagreen", alpha=0.7)

# Labels
plt.xlabel("Property Size (sq. ft.)")
plt.ylabel("Count")
plt.title("Property Size vs. Bedrooms & Bathrooms")
plt.legend(["Bedrooms", "Bathrooms"])

# Show plot
plt.show()

# %%
correlation_data = location_1_data[["Size (sq ft)", "Number of Bedrooms", "Number of Bathrooms"]]

# Compute correlation matrix
corr_matrix = correlation_data.corr()

# Plot heatmap
plt.figure(figsize=(6, 4))
sns.heatmap(corr_matrix, annot=True, cmap="Blues", fmt=".2f", linewidths=0.5)

# Titles
plt.title("Correlation Heatmap: Size vs. Bedrooms & Bathrooms")
plt.show()

# %%
# Are there more compact apartments or spacious houses in this location?
plt.figure(figsize=(8, 5))
sns.histplot(location_1_data["Size (sq ft)"], bins=30, kde=True, color="royalblue")

# Labels
plt.xlabel("Property Size (sq. ft.)")
plt.ylabel("Frequency")
plt.title("Distribution of Property Sizes in Location 1")

# Show plot
plt.show()

# %%
# What percentage of properties in Location 1 have garages, gardens, or swimming pools?
features = ["Has Garage", "Has Garden", "Has Swimming Pool"]
feature_counts = df[features].sum()

# Plot pie chart
plt.figure(figsize=(7, 7))
colors = ["royalblue", "seagreen", "gold"]
plt.pie(feature_counts, labels=features, autopct="%1.1f%%", colors=colors, startangle=140)

# Title
plt.title("Percentage of Properties with Garages, Gardens, or Swimming Pools in Location 1")

# Show plot
plt.show()

# %%
# Which type of facility is most common in Location 1?
facility_counts = location_1_data[["Has Garage", "Has Garden", "Has Swimming Pool"]].sum()

# Plot bar chart
plt.figure(figsize=(7, 5))
sns.barplot(x=facility_counts.index, y=facility_counts.values, palette="viridis")

# Labels
plt.xlabel("Facility Type")
plt.ylabel("Number of Properties")
plt.title("Most Common Facility in Location 1")

# Show plot
plt.show()
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\3061635575.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=facility_counts.index, y=facility_counts.values, palette="viridis")

# %%
correct_price_col = "Price ($)"

# Check unique values in facility columns
print(location_1_data[["Has Garage", "Has Garden", "Has Swimming Pool"]].head())
print(location_1_data[["Has Garage", "Has Garden", "Has Swimming Pool"]].dtypes)

# Convert facility columns to categorical if needed
for col in ["Has Garage", "Has Garden", "Has Swimming Pool"]:
    if location_1_data[col].dtype == 'bool':  # If values are True/False
        location_1_data[col] = location_1_data[col].map({True: "Yes", False: "No"})
    elif location_1_data[col].dtype in ['int64', 'float64']:  # If values are 1/0
        location_1_data[col] = location_1_data[col].map({1: "Yes", 0: "No"})

# Melt data
facility_data = location_1_data.melt(id_vars=[correct_price_col], 
                                     value_vars=["Has Garage", "Has Garden", "Has Swimming Pool"], 
                                     var_name="Facility", value_name="Has Facility")

# Print data to confirm changes
print(facility_data.head())

# Check if the data is empty before plotting
if facility_data.empty:
    print("Error: facility_data is empty. Check column names and values.")
else:
    # Plot boxplot
    plt.figure(figsize=(10, 6))
    sns.boxplot(x="Facility", y=correct_price_col, hue="Has Facility", data=facility_data, palette="viridis")

    # Labels
    plt.xlabel("Facility Type")
    plt.ylabel("Property Price ($)")
    plt.title("Impact of Facilities on Property Prices in Location 1")

    # Show plot
    plt.show()
# Out:
#      Has Garage  Has Garden  Has Swimming Pool
# 59        False       False              False
# 137       False        True              False
# 145       False       False              False
# 155        True        True               True
# 270        True        True              False
# Has Garage           bool
# Has Garden           bool
# Has Swimming Pool    bool
# dtype: object
#     Price ($)    Facility Has Facility
# 0   775017.24  Has Garage           No
# 1  1564652.43  Has Garage           No
# 2  1825894.36  Has Garage           No
# 3  1874575.95  Has Garage          Yes
# 4   332147.63  Has Garage          Yes
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\2930416521.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# What is the average construction year of properties in Location 1?
location_1_data = df[df["Location"] == "Location 1"]

# Plot
plt.figure(figsize=(10, 5))
sns.histplot(location_1_data["Year Built"], bins=20, kde=True, color="skyblue")

# Labels
plt.xlabel("Year Built")
plt.ylabel("Count")
plt.title("Distribution of Property Construction Years in Location 1")

# Show plot
plt.show()

# %%
# How many properties have undergone renovation, and does it impact their price?
df["Renovated"] = df["Last Renovation Year"].notna().map({True: "Yes", False: "No"})

# Plot boxplot
plt.figure(figsize=(8, 5))
sns.boxplot(x="Renovated", y="Price ($)", data=df, palette="viridis")

# Labels
plt.xlabel("Renovated Property")
plt.ylabel("Property Price ($)")
plt.title("Impact of Renovation on Property Prices")

# Show count of renovated vs. non-renovated properties
print(df["Renovated"].value_counts())

# Show plot
plt.show()
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\3767780776.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x="Renovated", y="Price ($)", data=df, palette="viridis")
# Renovated
# Yes    100000
# Name: count, dtype: int64

# %%
# Are older properties in Location 1 more affordable or expensive than newly built ones?
df["Property Age"] = 2025 - df["Year Built"]

# Filter only Location 1 data
location_1 = df[df["Location"] == "Location 1"]

# Plot age vs. price
plt.figure(figsize=(8, 5))
sns.scatterplot(x="Property Age", y="Price ($)", data=location_1, color="purple", alpha=0.7)

# Labels
plt.xlabel("Property Age (Years)")
plt.ylabel("Property Price ($)")
plt.title("Price Trend Based on Property Age in Location 1")

# Show plot
plt.show()

# %%
# What type of properties are most frequently bought or rented in Location 1?
location_1 = df[df["Location"] == "Location 1"]

# Count property types
property_counts = location_1["Property Type"].value_counts()

# Plot bar chart
plt.figure(figsize=(8, 5))
sns.barplot(x=property_counts.index, y=property_counts.values, palette="magma")

# Labels
plt.xlabel("Property Type")
plt.ylabel("Number of Properties")
plt.title("Most Commonly Bought/Rented Property Types in Location 1")

# Show count values on bars
for i, v in enumerate(property_counts.values):
    plt.text(i, v + 2, str(v), ha='center', fontsize=10)

plt.xticks(rotation=30)
plt.show()
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\750440315.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=property_counts.index, y=property_counts.values, palette="magma")

# %%
# Do buyers in Location 1 prefer larger homes with more facilities or smaller, affordable properties?
location_1 = df[df["Location"] == "Location 1"]

# Calculate total facilities for each property
facility_cols = ["Has Garage", "Has Garden", "Has Swimming Pool"]
location_1["Total Facilities"] = location_1[facility_cols].sum(axis=1)

# Scatter plot with trend line
plt.figure(figsize=(8, 5))
sns.scatterplot(x=location_1["Size (sq ft)"], y=location_1["Price ($)"], hue=location_1["Total Facilities"], palette="coolwarm", edgecolor="black")
sns.regplot(x=location_1["Size (sq ft)"], y=location_1["Price ($)"], scatter=False, color="black", line_kws={"linestyle": "dashed"})

# Labels
plt.xlabel("Property Size (sq ft)")
plt.ylabel("Property Price ($)")
plt.title("Buyer Preferences in Location 1: Large Homes vs. Affordable Properties")
plt.legend(title="Total Facilities", loc="upper left")

plt.show()
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\1981680538.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   location_1["Total Facilities"] = location_1[facility_cols].sum(axis=1)

# %%
# How does proximity to schools, hospitals, or shopping malls affect demand?
location_1 = df[df["Location"] == "Location 1"]

# Convert proximity to categorical (Near/Far based on median)
for facility in ["Nearby Schools", "Nearby Hospitals", "Nearby Shopping Malls"]:
    median_distance = location_1[facility].median()
    location_1[facility] = location_1[facility].apply(lambda x: "Near" if x <= median_distance else "Far")

# Melt data for visualization
demand_data = location_1.melt(id_vars=["Price ($)"], value_vars=["Nearby Schools", "Nearby Hospitals", "Nearby Shopping Malls"], 
                              var_name="Facility", value_name="Proximity")

# Plot boxplot
plt.figure(figsize=(10, 6))
sns.boxplot(x="Facility", y="Price ($)", hue="Proximity", data=demand_data, palette="coolwarm")

# Labels
plt.xlabel("Facility Type")
plt.ylabel("Property Price ($)")
plt.title("Impact of Proximity to Schools, Hospitals, and Shopping Malls on Property Demand")

plt.legend(title="Proximity", loc="upper left")
plt.show()
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\1887969459.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   location_1[facility] = location_1[facility].apply(lambda x: "Near" if x <= median_distance else "Far")
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\1887969459.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   location_1[facility] = location_1[facility].apply(lambda x: "Near" if x <= median_distance else "Far")
# ...

# %%
# conclusion
# The analysis of Location 1's real estate market reveals a balanced mix of affordability, investment potential, and demand-driven growth.

# %%
# top 5 property with highest prices
top5_properties = df.sort_values("Price ($)", ascending=False).head(5)
pista_palette = ["#22b0cf", "#22b0cf", "#22b0cf", "#22b0cf", "#22b0cf"]
# Plot a bar chart with Property ID on the x-axis and Price on the y-axis
plt.figure(figsize=(10, 6))
sns.barplot(x="Property ID", y="Price ($)", data=top5_properties, palette=pista_palette, edgecolor="black")

plt.xlabel("Property ID")
plt.ylabel("Price ($)")
plt.title("Top 5 Properties with Highest Prices")


# Add exact price labels on top of each bar
for i, row in top5_properties.iterrows():
    plt.text(x=top5_properties.index.get_loc(i), y=row["Price ($)"] + 10000, 
             s=f"${row['Price ($)']:.2f}", ha="center", fontsize=10)

plt.show()
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\1239643144.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="Property ID", y="Price ($)", data=top5_properties, palette=pista_palette, edgecolor="black")

# %%
print("Missing values in 'Property Type':", df["Property Type"].isnull().sum())

# Count occurrences of each property type
property_counts = df["Property Type"].value_counts()

# Display counts before plotting
print("Property Type Counts:\n", property_counts)

# Plot the bar graph if counts are reasonable
plt.figure(figsize=(10, 6))
plt.bar(property_counts.index, property_counts.values, color="#22b0cf", edgecolor="black")

# Adding labels on top of bars
for i, count in enumerate(property_counts.values):
    plt.text(i, count + 500, str(count), ha='center', fontsize=12, fontweight='bold')

# Labels and Title
plt.xlabel("Property Type")
plt.ylabel("Number of Properties")
plt.title("Most Common Property Types")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle="--", alpha=0.7)

# Show the plot
plt.show()
# Out:
# Missing values in 'Property Type': 0
# Property Type Counts:
#  Property Type
# Apartment    20096
# Condo        20071
# House        20049
# Villa        20032
# Townhouse    19752
# Name: count, dtype: int64

# %%
features = ["Has Garage", "Has Garden", "Has Swimming Pool"]

# Check if all required columns exist in the dataset
missing_features = [feature for feature in features if feature not in df.columns]
if missing_features:
    print(f"Error: The following columns are missing from the dataset: {missing_features}")
else:
    # Count the number of properties with each feature
    feature_counts = df[features].sum()

    # Calculate the percentage of total properties that have each feature
    total_properties = len(df)
    feature_percentages = (feature_counts / total_properties) * 100

    # Display the percentages
    print("Percentage of Properties with Garages, Gardens, or Swimming Pools:\n", feature_percentages)

    # Define the pista color palette
    pista_palette = ["#67d0cf", "#98e0cf", "#22b0cf"]  # All elements in the same color

    # Plot the pie chart with pista color
    plt.figure(figsize=(7, 7))
    plt.pie(feature_percentages, labels=features, autopct="%1.1f%%", colors=pista_palette, startangle=140, 
            wedgeprops={"edgecolor": "black"})

    # Title
    plt.title("Percentage of Properties with Garages, Gardens, or Swimming Pools")

    # Show the pie chart
    plt.show()
# Out:
# Percentage of Properties with Garages, Gardens, or Swimming Pools:
#  Has Garage           49.901
# Has Garden           50.079
# Has Swimming Pool    50.012
# dtype: float64

# %%
price_column = "Price ($)"

# Check if required columns exist
required_columns = ["Location", price_column, "Region", "Has Garage", "Has Garden", "Has Swimming Pool"]
missing_cols = [col for col in required_columns if col not in df.columns]
if missing_cols:
    raise KeyError(f"Missing columns in dataset: {missing_cols}")

# Convert facility columns to numeric
facility_columns = ["Has Garage", "Has Garden", "Has Swimming Pool"]
df[facility_columns] = df[facility_columns].apply(pd.to_numeric, errors="coerce").fillna(0)

# Filter properties in Central region
central_df = df[df["Region"] == "Central"]

# Ensure data exists for "Central"
if central_df.empty:
    raise ValueError("No data found for Central region. Check if 'Region' column values are correct.")

# Group by location and calculate average price
top_central_locations = central_df.groupby("Location").agg(avg_price=(price_column, "mean"))

# Sum up facilities
facility_sums = central_df.groupby("Location")[facility_columns].sum()

# Merge price and facility data
top_central_locations = top_central_locations.merge(facility_sums, left_index=True, right_index=True)

# Calculate total facility score
top_central_locations["facility_score"] = top_central_locations[facility_columns].sum(axis=1)

# Sort by price and facilities
top_central_locations = top_central_locations.sort_values(by=["avg_price", "facility_score"], ascending=[False, False])

# Select top 5 locations
top_5 = top_central_locations.head(5)

# Plot graph
fig, ax1 = plt.subplots(figsize=(10, 6))

# Bar chart for average price
sns.barplot(x=top_5.index, y=top_5["avg_price"], ax=ax1, color="#22b0cf", edgecolor="black")
ax1.set_ylabel("Average Price ($)", color="black")
ax1.set_xlabel("Location")
ax1.set_title("Top 5 Locations in Central Region by Price & Facilities")
ax1.tick_params(axis="y", labelcolor="black")

# Line plot for facility count
ax2 = ax1.twinx()
ax2.plot(top_5.index, top_5["facility_score"], color="red", marker="o", linestyle="-", linewidth=2, label="Facility Score")
ax2.set_ylabel("Total Facilities", color="red")
ax2.tick_params(axis="y", labelcolor="red")

# Show legend
ax2.legend(loc="upper right")

plt.xticks(rotation=45)
plt.show()

# %%
print(df.columns)
# Out:
# Index(['Property ID', 'Location', 'Region', 'Size (sq ft)',
#        'Number of Bedrooms', 'Number of Bathrooms', 'Year Built', 'Has Garage',
#        'Has Garden', 'Has Swimming Pool', 'Nearby Schools', 'Nearby Hospitals',
#        'Nearby Shopping Malls', 'Price ($)', 'Last Renovation Year',
#        'Property Type', 'Owner Name', 'Owner Contact', 'Renovated',
#        'Property Age'],
#       dtype='object')

# %%
# Define correct column names
price_column = "Price ($)"
facility_columns = ["Has Garage", "Has Garden", "Has Swimming Pool"]

# Check if required columns exist
required_columns = ["Location", price_column, "Region"] + facility_columns
missing_cols = [col for col in required_columns if col not in df.columns]
if missing_cols:
    raise KeyError(f"Missing columns in dataset: {missing_cols}")

# Convert facility columns to numeric
df[facility_columns] = df[facility_columns].apply(pd.to_numeric, errors="coerce").fillna(0)

# Filter properties in Central region
central_df = df[df["Region"] == "Central"]

# Ensure data exists for "Central"
if central_df.empty:
    raise ValueError("No data found for Central region. Check if 'Region' column values are correct.")

# Group by location and calculate average price
top_central_locations = central_df.groupby("Location").agg(avg_price=(price_column, "mean"))

# Sum up facilities for each location
facility_sums = central_df.groupby("Location")[facility_columns].sum()

# Merge price and facility data
top_central_locations = top_central_locations.merge(facility_sums, left_index=True, right_index=True)

# Convert values to percentages
top_central_locations["Price (%)"] = (top_central_locations["avg_price"] / top_central_locations["avg_price"].sum()) * 100
for facility in facility_columns:
    top_central_locations[f"{facility} (%)"] = (top_central_locations[facility] / top_central_locations[facility].sum()) * 100

# Sort by price percentage
top_central_locations = top_central_locations.sort_values(by=["Price (%)"], ascending=[False])

# Select top 5 locations
top_5 = top_central_locations.head(5)

# Define shades of blue for consistency
price_color = "#003f5c"  # Dark Blue for Price
facility_colors = ["#0077b6", "#48cae4", "#90e0ef"]  # Lighter Blue shades for Facilities

# Plot graph
fig, ax1 = plt.subplots(figsize=(12, 6))

# Bar chart for price percentage (Darker Blue)
bars1 = sns.barplot(x=top_5.index, y=top_5["Price (%)"], ax=ax1, color=price_color, edgecolor="black", label="Price (%)")
ax1.set_ylabel("Price (%)", color="black")
ax1.set_xlabel("Location")
ax1.set_title("Top 5 Locations in Central Region: Price & Facility Percentage Comparison")
ax1.tick_params(axis="y", labelcolor="black")

# Add labels on price bars
for bar in bars1.patches:
    ax1.annotate(f"{bar.get_height():.1f}%", 
                 (bar.get_x() + bar.get_width() / 2, bar.get_height()), 
                 ha="center", va="bottom", fontsize=10, color="black", fontweight="bold")

# Create a secondary Y-axis for facilities
ax2 = ax1.twinx()

# Stacked bar chart for facilities percentage using Matplotlib
bottom_values = np.zeros(len(top_5))
for i, facility in enumerate(facility_columns):
    bars2 = ax2.bar(top_5.index, top_5[f"{facility} (%)"], bottom=bottom_values, color=facility_colors[i], alpha=0.8, label=f"{facility} (%)")
    
    # Add labels on stacked facility bars
    for bar in bars2:
        height = bar.get_height()
        if height > 0:
            ax2.annotate(f"{height:.1f}%", 
                         (bar.get_x() + bar.get_width() / 2, bar.get_y() + height / 2), 
                         ha="center", va="center", fontsize=10, color="white", fontweight="bold")

    bottom_values += top_5[f"{facility} (%)"].values

ax2.set_ylabel("Facilities (%)", color="black")
ax2.tick_params(axis="y", labelcolor="black")

# Create a combined legend
ax1.legend(loc="upper left")
ax2.legend(loc="upper right")

plt.xticks(rotation=45)
plt.show()

# %%
#  Define necessary columns
price_column = "Price ($)"
facility_columns = ["Has Garage", "Has Garden", "Has Swimming Pool"]

# Convert facility columns to numeric
df[facility_columns] = df[facility_columns].apply(pd.to_numeric, errors="coerce").fillna(0)

# Filter data for Location 32
location_32_df = df[df["Location"] == "Location 32"]

# Check if data exists for Location 32
if location_32_df.empty:
    raise ValueError("No data found for Location 32. Please check if the location name is correct.")

# Compute correlation matrix
correlation_matrix = location_32_df[[price_column] + facility_columns].corr()

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap="Blues", linewidths=0.5, fmt=".2f")
plt.title("Correlation Between Property Prices and Facilities (Location 32)")
plt.show()

# %%
df_location_32 = df[df["Location"] == "Location 32"]

# Group by Year Built and calculate the average price
df_location_32_grouped = df_location_32.groupby("Year Built")["Price ($)"].mean().reset_index()

# Plot the line graph
plt.figure(figsize=(10, 5))
plt.plot(df_location_32_grouped["Year Built"], df_location_32_grouped["Price ($)"], marker='o', linestyle='-')

# Labels and title
plt.xlabel("Year Built")
plt.ylabel("Average Property Price ($)")
plt.title("Property Price Trends in Location 32")
plt.grid(True)
plt.show()

# %%
# Filter data for Location 32
df_location_32 = df[df["Location"] == "Location 32"]

# Check if 'Last Renovation Year' column exists
if "Last Renovation Year" in df.columns:
    # Group by Last Renovation Year and calculate the average price
    df_last_renovation_grouped = df_location_32.groupby("Last Renovation Year")["Price ($)"].mean().reset_index()

    # Plot the line graph
    plt.figure(figsize=(10, 5))
    plt.plot(df_last_renovation_grouped["Last Renovation Year"], df_last_renovation_grouped["Price ($)"], marker='o', linestyle='-')

    # Labels and title
    plt.xlabel("Last Renovation Year")
    plt.ylabel("Average Property Price ($)")
    plt.title("Property Prices Based on Last Renovation Year in Location 32")
    plt.grid(True)
    plt.show()
else:
    print("The dataset does not contain a 'Last Renovation Year' column.")

# %%
# Filter for Location 32
df_location32 = df[df['Location'] == 32]

# Set plot style
sns.set_style("whitegrid")

# Create subplots for each amenity
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# Schools vs Property Prices
sns.boxplot(x=df_location32['Nearby Schools'], y=df_location32['Price ($)'], ax=axes[0])
axes[0].set_title("Impact of Schools on Property Prices")
axes[0].set_xlabel("Number of Nearby Schools")
axes[0].set_ylabel("Property Price ($)")

# Hospitals vs Property Prices
sns.boxplot(x=df_location32['Nearby Hospitals'], y=df_location32['Price ($)'], ax=axes[1])
axes[1].set_title("Impact of Hospitals on Property Prices")
axes[1].set_xlabel("Number of Nearby Hospitals")
axes[1].set_ylabel("Property Price ($)")

# Malls vs Property Prices
sns.boxplot(x=df_location32['Nearby Shopping Malls'], y=df_location32['Price ($)'], ax=axes[2])
axes[2].set_title("Impact of Malls on Property Prices")
axes[2].set_xlabel("Number of Nearby Malls")
axes[2].set_ylabel("Property Price ($)")

# Show plots
plt.tight_layout()
plt.show()

# %%
# Filter data for Location 32
df_location_32 = df[df['Location'] == 'Location 32']

# Check if data is available
if df_location_32.empty:
    print("No data available for Location 32")
else:
    # Calculate average property price for different numbers of nearby facilities
    avg_price_schools = df_location_32.groupby('Nearby Schools')['Price ($)'].mean()
    avg_price_hospitals = df_location_32.groupby('Nearby Hospitals')['Price ($)'].mean()
    avg_price_malls = df_location_32.groupby('Nearby Shopping Malls')['Price ($)'].mean()

    # Create bar plots
    fig, axes = plt.subplots(1, 3, figsize=(18, 5))

    # Schools vs. Price
    sns.barplot(x=avg_price_schools.index, y=avg_price_schools.values, ax=axes[0], palette='Blues')
    axes[0].set_title("Impact of Schools on Property Prices")
    axes[0].set_xlabel("Number of Nearby Schools")
    axes[0].set_ylabel("Average Property Price ($)")

    # Hospitals vs. Price
    sns.barplot(x=avg_price_hospitals.index, y=avg_price_hospitals.values, ax=axes[1], palette='Reds')
    axes[1].set_title("Impact of Hospitals on Property Prices")
    axes[1].set_xlabel("Number of Nearby Hospitals")
    axes[1].set_ylabel("Average Property Price ($)")

    # Malls vs. Price
    sns.barplot(x=avg_price_malls.index, y=avg_price_malls.values, ax=axes[2], palette='Greens')
    axes[2].set_title("Impact of Malls on Property Prices")
    axes[2].set_xlabel("Number of Nearby Malls")
    axes[2].set_ylabel("Average Property Price ($)")

    plt.tight_layout()
    plt.show()
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\71824219.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_price_schools.index, y=avg_price_schools.values, ax=axes[0], palette='Blues')
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\71824219.py:24: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=avg_price_hospitals.index, y=avg_price_hospitals.values, ax=axes[1], palette='Reds')
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\71824219.py:30: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
# ...

# %%
average_prices = df.groupby("Property Type")["Price ($)"].mean().sort_values(ascending=False)

# Step 3: Plot the results with color and black edge
plt.figure(figsize=(10, 5))
bars = average_prices.plot(kind="bar", color="#22b0cf", edgecolor="black")

# Step 4: Add labels on top of bars
for bar in bars.patches:
    plt.text(bar.get_x() + bar.get_width()/2, bar.get_height(), 
             f'${bar.get_height():,.0f}', ha='center', va='bottom', 
             fontsize=12, fontweight='bold')

# Step 5: Customize the chart
plt.xlabel("Property Type")
plt.ylabel("Average Price")
plt.title("Average Price Comparison by Property Type")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the chart
plt.show()

# %%
amenities = ['Has Garage', 'Has Garden', 'Has Swimming Pool']

# Group by property type and calculate the percentage of properties with each amenity
property_amenities = df.groupby('Property Type')[amenities].mean() * 100  # Convert to percentage

# Define blue shades for the bars
colors = ['#1E88E5', '#42A5F5', '#90CAF9']  # Different shades of blue

# Plot the graph
property_amenities.plot(kind='bar', figsize=(10, 6), color=colors, edgecolor='black')

# Add labels and title
plt.xlabel("Property Type")
plt.ylabel("Percentage of Properties with Amenity")
plt.title("Comparison of Amenities Across Property Types")
plt.legend(title="Amenities")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
amenities = ['Has Garage', 'Has Garden', 'Has Swimming Pool']

# 1. Demand Analysis: Count of Listings per Property Type
demand_volume = df['Property Type'].value_counts().reset_index()
demand_volume.columns = ['Property Type', 'Listing Count']

# 2. Price Trends: Average Price per Property Type
price_trends = df.groupby('Property Type')['Price ($)'].mean().reset_index()

# 3. Amenities Comparison: Calculate percentage of properties with each amenity
property_amenities = df.groupby('Property Type')[amenities].mean() * 100  # Convert to percentage

# Plot 1: Demand Analysis (Number of Listings)
plt.figure(figsize=(14, 4))
plt.subplot(1, 3, 1)
plt.bar(demand_volume['Property Type'], demand_volume['Listing Count'], color='#22b0cf', edgecolor='black')
plt.xlabel("Property Type")
plt.ylabel("Number of Listings")
plt.title("Demand Based on Listings")
plt.xticks(rotation=45)

# Plot 2: Price Trends
plt.subplot(1, 3, 2)
plt.bar(price_trends['Property Type'], price_trends['Price ($)'], color='#1f77b4', edgecolor='black')
plt.xlabel("Property Type")
plt.ylabel("Average Price")
plt.title("Average Price Comparison")
plt.xticks(rotation=45)

# Plot 3: Amenities Comparison
property_amenities.plot(kind='bar', figsize=(14, 4), color=['#1976D2', '#42A5F5', '#90CAF9'], edgecolor='black', ax=plt.subplot(1, 3, 3))
plt.xlabel("Property Type")
plt.ylabel("Percentage of Properties with Amenity")
plt.title("Comparison of Amenities Across Property Types")
plt.legend(title="Amenities")
plt.xticks(rotation=45)

# Show all plots
plt.tight_layout()
plt.show()

# %%
time_column = "Year" if "Year" in df.columns else None

# 1. Count of listings per property type (proxy for sales/rentals)
property_demand = df['Property Type'].value_counts().reset_index()
property_demand.columns = ['Property Type', 'Listing Count']

# 2. Trend Over Time (if time column is available)
if time_column:
    trend_data = df.groupby([time_column, 'Property Type']).size().unstack().fillna(0)

# Plot 1: Demand based on Listings
plt.figure(figsize=(12, 5))
plt.bar(property_demand['Property Type'], property_demand['Listing Count'], color='#22b0cf', edgecolor='black')
plt.xlabel("Property Type")
plt.ylabel("Number of Listings")
plt.title("Demand Based on Listings (Sales/Rental Proxy)")
plt.xticks(rotation=45)
plt.show()

# Plot 2: Sales/Rental Trends Over Time (if time data exists)
if time_column:
    trend_data.plot(figsize=(12, 5), marker='o', colormap='Blues')
    plt.xlabel("Year")
    plt.ylabel("Number of Listings (Sales/Rentals Proxy)")
    plt.title("Sales/Rental Trends Over Time by Property Type")
    plt.legend(title="Property Type")
    plt.grid(axis='y', linestyle='--', alpha=0.7)
    plt.show()

# %%
time_column = "Year" if "Year" in df.columns else None

if time_column:
    # Group data by year and property type
    trend_data = df.groupby([time_column, 'Property Type']).size().unstack().fillna(0)
    
    # Apply rolling mean for smoother trends (adjust window size as needed)
    trend_data = trend_data.rolling(window=5, min_periods=1).mean()

    # Plot
    plt.figure(figsize=(12, 6))
    for col in trend_data.columns:
        if col == "Apartment":
            plt.plot(trend_data.index, trend_data[col], label=col, linewidth=2.5, color='darkblue')
        else:
            plt.plot(trend_data.index, trend_data[col], label=col, linestyle="--", alpha=0.6)

    # Labels and title
    plt.xlabel("Year")
    plt.ylabel("Number of Listings (Sales/Rentals Proxy)")
    plt.title("Smoothed Sales/Rental Trends Over Time by Property Type")
    plt.legend(title="Property Type")
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Show plot
    plt.show()

# %%
avg_distances = df.groupby('Property Type')[['Nearby Schools', 'Nearby Hospitals', 'Nearby Shopping Malls']].mean()

# Plot the bar chart
plt.figure(figsize=(10, 6))
avg_distances.plot(kind='bar', colormap='Blues', edgecolor='black', width=0.7)

# Labels and title
plt.xlabel("Property Type")
plt.ylabel("Average Distance (km)")
plt.title("Average Distance to Essential Services by Property Type")
plt.legend(title="Essential Services")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Show the plot
plt.show()

# %%
# Ensure column names are stripped of spaces
df.columns = df.columns.str.strip()

# Use the correct column name found in print(df.columns)
correct_column_name = 'Size (sq ft)'  # Update this with the exact name

# Check if the column exists
if correct_column_name in df.columns:
    # Group by 'Property Type' and calculate average property size
    avg_size = df.groupby('Property Type')[correct_column_name].mean().reset_index()

    # Plot the bar chart
    plt.figure(figsize=(10, 6))
    bars = plt.bar(avg_size['Property Type'], avg_size[correct_column_name], color='#22b0cf', edgecolor='black')

    # Add labels on top of bars
    for bar in bars:
        yval = bar.get_height()
        plt.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 2), ha='center', va='bottom', fontsize=10, fontweight='bold')

    # Add labels and title
    plt.xlabel("Property Type")
    plt.ylabel("Average Property Size (sq ft)")
    plt.title("Average Size of Different Property Types")
    plt.xticks(rotation=45)
    plt.grid(axis='y', linestyle='--', alpha=0.7)

    # Show the plot
    plt.show()
else:
    print(f"Column '{correct_column_name}' not found in the dataset. Please check column names.")

# %%
plt.figure(figsize=(12, 6))
sns.lmplot(x='Size (sq ft)', y='Price ($)', hue='Property Type', data=df, aspect=1.5, scatter_kws={'alpha':0.5})

plt.xlabel("Property Size (sq ft)")
plt.ylabel("Price ($)")
plt.title("Correlation Between Property Size and Price Across Property Types")
plt.show()

# Boxplot for price distribution by size category and property type
df['Size Category'] = pd.qcut(df['Size (sq ft)'], q=4, labels=["Small", "Medium", "Large", "Very Large"])

plt.figure(figsize=(12, 6))
sns.boxplot(x='Size Category', y='Price ($)', hue='Property Type', data=df)
plt.xlabel("Property Size Category")
plt.ylabel("Price ($)")
plt.title("Price Distribution Across Different Property Sizes by Property Type")
plt.show()

# %%
bins = [0, 500, 1000, 1500, 2000, 2500, 3000, 3500, 4000]
labels = ["<500", "500-1000", "1000-1500", "1500-2000", "2000-2500", "2500-3000", "3000-3500", "3500+"]

# Filter apartments
apartments = df[df["Property Type"] == "Apartment"]

# Categorize apartments into size bins
apartments["Size Range"] = pd.cut(apartments["Size (sq ft)"], bins=bins, labels=labels)

# Count frequency of each size range
size_distribution = apartments["Size Range"].value_counts().sort_index()

# Plot distribution
plt.figure(figsize=(10, 5))
sns.barplot(x=size_distribution.index, y=size_distribution.values, palette="Blues_r")
plt.xlabel("Apartment Size Range (sq ft)")
plt.ylabel("Count of Properties")
plt.title("Most Common Property Size Ranges for Apartments")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\552029272.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apartments["Size Range"] = pd.cut(apartments["Size (sq ft)"], bins=bins, labels=labels)
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\552029272.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=size_distribution.index, y=size_distribution.values, palette="Blues_r")

# %%
bins = [0, 800, 1500, 2500, 4000]  
labels = ["Small (<800 sqft)", "Medium (800-1500 sqft)", "Large (1500-2500 sqft)", "Extra Large (>2500 sqft)"]

# Filter apartments
apartments = df[df["Property Type"] == "Apartment"]

# Categorize apartments into size bins
apartments["Size Category"] = pd.cut(apartments["Size (sq ft)"], bins=bins, labels=labels)

# Count sales/rental transactions per size category
sales_distribution = apartments.groupby("Size Category")["Sales"].sum().reset_index()

# Plot distribution
plt.figure(figsize=(10, 5))
sns.barplot(x=sales_distribution["Size Category"], y=sales_distribution["Sales"], palette="coolwarm")
plt.xlabel("Apartment Size Category")
plt.ylabel("Number of Sales/Rentals")
plt.title("Customer Preference: Smaller vs. Larger Apartments")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\3966855353.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apartments["Size Category"] = pd.cut(apartments["Size (sq ft)"], bins=bins, labels=labels)
# C:\Users\Satyam\AppData\Local\Temp\ipykernel_9912\3966855353.py:11: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   sales_distribution = apartments.groupby("Size Category")["Sales"].sum().reset_index()
# ---------------------------------------------------------------------------
# ...
